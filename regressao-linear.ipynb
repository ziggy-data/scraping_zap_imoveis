# %% [markdown]
# # Regressão linear

# %% [markdown]
# ## Importando as bibliotecas
# <hr style='border: 2px solid red;'>

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# !pip show pandas
# !pip show numpy
# !pip show matplotlib
# !pip show scikit-learn
# Out:
# Name: pandas
# Version: 1.3.4
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: /home/king/anaconda3/lib/python3.9/site-packages
# Requires: python-dateutil, pytz, numpy
# Required-by: statsmodels, seaborn
# Name: numpy
# Version: 1.20.3
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: /home/king/anaconda3/lib/python3.9/site-packages
# Requires:
# Required-by: tifffile, tables, statsmodels, seaborn, scipy, scikit-learn, scikit-image, PyWavelets, pyerfa, patsy, pandas, numexpr, numba, mkl-random, mkl-fft, matplotlib, imageio, imagecodecs, h5py, daal4py, Bottleneck, bokeh, bkcharts, astropy
# Name: matplotlib
# Version: 3.4.3
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /home/king/anaconda3/lib/python3.9/site-packages
# Requires: pillow, kiwisolver, pyparsing, numpy, cycler, python-dateutil
# Required-by: seaborn, scikit-image, jupyterthemes
# Name: scikit-learn
# Version: 0.24.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /home/king/anaconda3/lib/python3.9/site-packages
# Requires: joblib, scipy, numpy, threadpoolctl
# Required-by: scikit-learn-intelex

# %%
dados = pd.read_csv('dados/dataset.csv', sep=';')
dados
# Out:
#           value                                          descricao  \
# 0        95.000  Apartamento no térreo no Condomínio Vivenda da...
# 1       330.000    Apartamento   3 quartos   Coração Eucarístic...
# 2     4.700.000    4 SUÍTES   DEPENDENCIA DE EMPREGADA    205M²...
# 3       400.000  Casa em condomínio Village Santa Mônica   Várz...
# 4       265.000    3 Quartos (Sendo 1 Suíte Master)   2 Banheir...
# ...         ...                                                ...
# 4795    200.000  Situacao imovel: Lançamento __________________...
# 4796    470.000  Esta Unidade está Decorada Hall de Entrada 100...
# 4797    530.000  Aceita financiamento bancário, documentação de...
# 4798    770.000  Casa de Condomínio para venda em Jardim Vista ...
# 4799  1.650.000  Apartamento Reformado com 2 dormitórios à vend...
#
#                                           endereco  quartos  garagem  \
# 0                         Inhoaíba, Rio de Janeiro        2        0
# 1     Rua Dom Aristides Porto, Coração Eucarístico        3        1
# 2                Riviera de São Lourenço, Bertioga        4        3
# 3         Rodovia Amaral Peixoto, Várzea das Moças        3        3
# 4                    Avenida Independência, Unamar        3        4
# ...                                            ...      ...      ...
# 4795                             Jundiai, Anápolis        0        0
# 4796                      Rua Taubaté, Baeta Neves        2        1
# 4797                Rua Colômbia, Vila Guilhermina        2        1
# 4798                Jardim Vista Verde, Indaiatuba        3        2
# 4799                            Jardins, São Paulo        2        1
#
#       banheiro   m2        novidade
# 0            1   50  Super destaque
# 1            2   95  Super destaque
# 2            4  180  Super destaque
# 3            3  247         Nenhuma
# 4            2   99         Nenhuma
# ...        ...  ...             ...
# 4795         0   35         Nenhuma
# 4796         1   55         Nenhuma
# 4797         2   85         Nenhuma
# 4798         2  175         Nenhuma
# 4799         3  110         Nenhuma
#
# [4800 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()

# %%
x = dados[['garagem','banheiros','quartos','novidade','m2']]
y = dados['valor']

# %%
X_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.30, random_state=101)

# %%
modelo.fit(X_train,y_train)
